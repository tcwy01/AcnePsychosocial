# %% [markdown]
# Loading and inspecting data

# %%
#Loading in pandas
import pandas as pd

# %%
#Loading in data 
acne_data = pd.read_csv('Z:/270418_91.csv')
acne_data
# Out:
# C:\Users\tammy\AppData\Local\Temp\ipykernel_25656\1952429446.py:1: DtypeWarning: Columns (0,4,5,6,7,8,10,11,12,13,14,15,16,18,19,20,21,22,23,24,32,40,41,43,318,328,553,562,569,650,651,704,705,712,765,766,767,835,836,837,838,865,1083,1778,2203,2427,2443,3953,4114,4135,4301,4391) have mixed types. Specify dtype option on import or set low_memory=False.
#   acne_data = pd.read_csv('Z:/270418_91.csv')
#         ID Repeat_Visit Consented_Date Micro_RNA OldConsent_Q1 OldConsent_Q2  \
# 0        1                    8/8/2001                       1             1
# 1        2            1     10/10/2007                       1             1
# 2        3                  10/24/2007                       1             1
# 3        4                  10/10/2007                       1             1
# 4        5                  10/31/2007                       3             3
# ...    ...          ...            ...       ...           ...           ...
# 2239  2313
# 2240  2314
# 2241  2315
# ...

# %%
#Inspecting data
acne_data.describe()
# Out:
#           ID Repeat_Visit Consented_Date Micro_RNA OldConsent_Q1  \
# count   2244         2244           2244      2244          2244
# unique  2219            2            773         4            10
# top
# freq      12         2027             54      2217          1201
#
#        OldConsent_Q2 OldConsent_Q3 OldConsent_Q4 OldConsent_Q5 MissingForms  \
# count           2244          2244          2244          2244         2244
# unique            10            10            11            12            2
# top
# freq            1201          1201          1201          1326         2228
#
#         ... RetestVas7 RetestVas8 RetestVas9 RetestVas10 RetestVas11  \
# count   ...       2244       2244       2244        2244        2244
# unique  ...         14         13         13          15          15
# top     ...
# freq    ...       1693       1687       1689        1689        1685
#
#        RetestVas12 RetestVas13 RetestVas14 RetestVas15 PrimaryLast
# ...

# %%
#Loading in missingno
#! pip install missingno
import missingno as msno

#Inspecting missing values 
msno.matrix(acne_data)
# Out:
# <Axes: >

# %% [markdown]
# Preprocessing
